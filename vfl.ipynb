# %% [markdown]
# <a href="https://colab.research.google.com/github/samaralrubaye-AI/ali-alawi/blob/main/vfl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('firstcode')
# Out:
# firstcode
